# %% [markdown]
# ### >> All Required Models

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.decomposition import FastICA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier

pipe_pca_mlp = Pipeline([('pca', PCA(n_components=2)), ('mlp', MLPClassifier(hidden_layer_sizes=(15,10,5), max_iter=500))])
pipe_ica_mlp = Pipeline([('ica', FastICA(n_components = 2)), ('mlp', MLPClassifier(hidden_layer_sizes=(15,10,5), max_iter=500))])
pipe_lda_mlp = Pipeline([('lda', LinearDiscriminantAnalysis(n_components = 1)), ('mlp', MLPClassifier(hidden_layer_sizes=(15,10,5), max_iter=500))])

# %%
import tensorflow as tf

def SigXNet(input_shape, classes, X_train, Y_train, X_test, Y_test):
  model = tf.keras.models.Sequential([
      tf.keras.layers.Input(shape=input_shape),

      tf.keras.layers.MaxPooling1D(),
      tf.keras.layers.Conv1D(26, kernel_size=7, strides=1, padding='valid'),
      tf.keras.layers.LeakyReLU(),
      tf.keras.layers.BatchNormalization(),
      
      tf.keras.layers.MaxPooling1D(),
      tf.keras.layers.Conv1D(13, kernel_size=5, strides=1, padding='valid'),
      tf.keras.layers.LeakyReLU(),
      tf.keras.layers.BatchNormalization(),
      
      tf.keras.layers.MaxPooling1D(),
      tf.keras.layers.Conv1D(7, kernel_size=3, strides=1, padding='valid'),
      tf.keras.layers.LeakyReLU(),
      tf.keras.layers.BatchNormalization(),
      
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(15, activation = 'selu'),
      tf.keras.layers.Dense(10, activation = 'selu'),
      tf.keras.layers.Dense(5, activation = 'selu'),
      tf.keras.layers.Dense(classes, activation='sigmoid')
  ], name = "SigXNet")

  model.compile(optimizer = tf.keras.optimizers.SGD(lr = 1e-3), loss=tf.keras.losses.categorical_crossentropy, metrics = ['accuracy'])
  model.summary()

  onehot_y_train = tf.keras.utils.to_categorical(Y_train)
  onehot_y_test = tf.keras.utils.to_categorical(Y_test)

  reducelr = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_accuracy", mode="max", patience=3, verbose=2)
  history = model.fit(X_train, onehot_y_train, validation_data = (X_test, onehot_y_test), epochs = 50, callbacks = reducelr)

  return model, history

# %% [markdown]
# ## 1. EEG Classification and Comparison
#  => Dataset: Epileptic Seizure Recognition

# %%
eeg_data_path = '/content/drive/MyDrive/Datasets/Epileptic Seizure Recognition Data Set.csv'

# %%
import pandas as pd
import numpy as np

# %%
eeg_df = pd.read_csv(eeg_data_path)

# Dropping the extra column
eeg_df = eeg_df.drop(['ID'], axis = 1)

# Seperating the samples and labels data
x_data = eeg_df.drop('y', axis = 1)
y_data = eeg_df[['y']]

# %%
# Standard Scaling Data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(x_data)
x_data_scaled = scaler.transform(x_data)

# %%
class0 = [2, 3, 4, 5]
class1 = [1]

for index, row in y_data.iterrows():
    if row['y'] in class0:
      row['y'] = 0
    elif row['y'] in class1:
      row['y'] = 1

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data_scaled, y_data, test_size = 0.20, random_state = 1)

# %%
pipe_pca_mlp.fit(x_train, y_train.to_numpy().ravel())
# Out:
# Pipeline(memory=None,
#          steps=[('pca',
#                  PCA(copy=True, iterated_power='auto', n_components=2,
#                      random_state=None, svd_solver='auto', tol=0.0,
#                      whiten=False)),
#                 ('mlp',
#                  MLPClassifier(activation='relu', alpha=0.0001,
#                                batch_size='auto', beta_1=0.9, beta_2=0.999,
#                                early_stopping=False, epsilon=1e-08,
#                                hidden_layer_sizes=(15, 10, 5),
#                                learning_rate='constant',
#                                learning_rate_init=0.001, max_fun=15000,
#                                max_iter=500, momentum=0.9, n_iter_no_change=10,
#                                nesterovs_momentum=True, power_t=0.5,
#                                random_state=None, shuffle=True, solver='adam',
#                                tol=0.0001, validation_fraction=0.1,
#                                verbose=False, warm_start=False))],
#          verbose=False)

# %%
pipe_ica_mlp.fit(x_train, y_train.to_numpy().ravel())
# Out:
# Pipeline(memory=None,
#          steps=[('ica',
#                  FastICA(algorithm='parallel', fun='logcosh', fun_args=None,
#                          max_iter=200, n_components=2, random_state=None,
#                          tol=0.0001, w_init=None, whiten=True)),
#                 ('mlp',
#                  MLPClassifier(activation='relu', alpha=0.0001,
#                                batch_size='auto', beta_1=0.9, beta_2=0.999,
#                                early_stopping=False, epsilon=1e-08,
#                                hidden_layer_sizes=(15, 10, 5),
#                                learning_rate='constant',
#                                learning_rate_init=0.001, max_fun=15000,
#                                max_iter=500, momentum=0.9, n_iter_no_change=10,
#                                nesterovs_momentum=True, power_t=0.5,
#                                random_state=None, shuffle=True, solver='adam',
#                                tol=0.0001, validation_fraction=0.1,
#                                verbose=False, warm_start=False))],
#          verbose=False)

# %%
pipe_lda_mlp.fit(x_train, y_train.to_numpy().ravel())
# Out:
# Pipeline(memory=None,
#          steps=[('lda',
#                  LinearDiscriminantAnalysis(n_components=1, priors=None,
#                                             shrinkage=None, solver='svd',
#                                             store_covariance=False,
#                                             tol=0.0001)),
#                 ('mlp',
#                  MLPClassifier(activation='relu', alpha=0.0001,
#                                batch_size='auto', beta_1=0.9, beta_2=0.999,
#                                early_stopping=False, epsilon=1e-08,
#                                hidden_layer_sizes=(15, 10, 5),
#                                learning_rate='constant',
#                                learning_rate_init=0.001, max_fun=15000,
#                                max_iter=500, momentum=0.9, n_iter_no_change=10,
#                                nesterovs_momentum=True, power_t=0.5,
#                                random_state=None, shuffle=True, solver='adam',
#                                tol=0.0001, validation_fraction=0.1,
#                                verbose=False, warm_start=False))],
#          verbose=False)

# %%
print('(PCA + MLP) Training Accuracy: ' + str(pipe_pca_mlp.score(x_train, y_train.to_numpy().ravel())) + ' Testing Accuracy: ' + str(pipe_pca_mlp.score(x_test, y_test.to_numpy().ravel())))
print('(ICA + MLP) Training Accuracy: ' + str(pipe_ica_mlp.score(x_train, y_train.to_numpy().ravel())) + ' Testing Accuracy: ' + str(pipe_ica_mlp.score(x_test, y_test.to_numpy().ravel())))
print('(LCA + MLP) Training Accuracy: ' + str(pipe_lda_mlp.score(x_train, y_train.to_numpy().ravel())) + ' Testing Accuracy: ' + str(pipe_lda_mlp.score(x_test, y_test.to_numpy().ravel())))
# Out:
# (PCA + MLP) Training Accuracy: 0.947391304347826 Testing Accuracy: 0.938695652173913
# (ICA + MLP) Training Accuracy: 0.9451086956521739 Testing Accuracy: 0.9373913043478261
# (LCA + MLP) Training Accuracy: 0.8635869565217391 Testing Accuracy: 0.8408695652173913

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import itertools

def plot_confusion_matrix(cm, target_names, title = None, cmap = None, normalize = False):
    """
    Given a sklearn confusion matrix (cm), make a plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(4, 4))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title('Confusion Matrix ' + title)
    # plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('\nPredicted label\n\nAccuracy={:0.4f}; Misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

def plot_classification_report(cr, figsize = (10, 5), title = None, cmap = 'Purples'):
  acc_f1 = cr['accuracy']
  acc_support = cr['weighted avg']['support']
  acc_precision = None
  acc_recall = None

  cr['accuracy'] = {'precision': acc_precision, 'recall': acc_recall, 'f1-score': acc_f1, 'support': acc_support}

  plt.figure(figsize = figsize)
  plt.title('Classification Report ' + title)
  sns.heatmap(pd.DataFrame(cr).T, cmap = cmap, annot = True, cbar = False, fmt='g')
  plt.show()

def plot_cr_cm(model, x_data, y_true, labels, target_names, title = None, cmap = 'Purples', y_preds = None, model_type = 'keras'):
  if model_type == 'sklearn':
    y_preds = model.predict(x_data)

  confusionmatrix = confusion_matrix(y_true, y_preds)
  plot_confusion_matrix(cm = confusionmatrix, target_names = target_names, title = title, cmap = cmap)
  
  print('\n')
  classificationreport = classification_report(y_true, y_preds, labels = labels, target_names = target_names, output_dict = True)
  plot_classification_report(cr = classificationreport, title = title, cmap = cmap)

# %%
plot_cr_cm(pipe_pca_mlp, x_train, y_train, [0, 1], ['Non Epileptic', 'Epileptic'], 'PCA + MLP (Training)', model_type = 'sklearn')
plot_cr_cm(pipe_pca_mlp, x_test, y_test, [0, 1], ['Non Epileptic', 'Epileptic'], 'PCA + MLP (Testing)', model_type = 'sklearn')

# %%
plot_cr_cm(pipe_ica_mlp, x_train, y_train, [0, 1], ['Non Epileptic', 'Epileptic'], 'ICA + MLP (Training)', model_type = 'sklearn')
plot_cr_cm(pipe_ica_mlp, x_test, y_test, [0, 1], ['Non Epileptic', 'Epileptic'], 'ICA + MLP (Testing)', model_type = 'sklearn')

# %%
plot_cr_cm(pipe_lda_mlp, x_train, y_train, [0, 1], ['Non Epileptic', 'Epileptic'], 'LDA + MLP (Training)', model_type = 'sklearn')
plot_cr_cm(pipe_lda_mlp, x_test, y_test, [0, 1], ['Non Epileptic', 'Epileptic'], 'LDA + MLP (Testing)', model_type = 'sklearn')

# %%
model_eeg, history_eeg = SigXNet(input_shape=(178, 1), classes=2, X_train=x_train.reshape((x_train.shape[0], x_train.shape[1], 1)), Y_train=y_train.to_numpy(), X_test=x_test.reshape((x_test.shape[0], x_test.shape[1], 1)), Y_test=y_test.to_numpy())
# Out:
# Model: "SigXNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# max_pooling1d_3 (MaxPooling1 (None, 89, 1)             0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 83, 26)            208
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 83, 26)            0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 83, 26)            104
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 41, 26)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 37, 13)            1703
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 37, 13)            0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 37, 13)            52
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 18, 13)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 16, 7)             280
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 16, 7)             0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 7)             28
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 112)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 15)                1695
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                160
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 55
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 12
# =================================================================
# Total params: 4,297
# Trainable params: 4,205
# Non-trainable params: 92
# _________________________________________________________________
# Epoch 1/50
# 288/288 [==============================] - 3s 6ms/step - loss: 0.4928 - accuracy: 0.8073 - val_loss: 0.2173 - val_accuracy: 0.9174
# Epoch 2/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.1969 - accuracy: 0.9284 - val_loss: 0.1591 - val_accuracy: 0.9448
# Epoch 3/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.1552 - accuracy: 0.9458 - val_loss: 0.1439 - val_accuracy: 0.9517
# Epoch 4/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.1455 - accuracy: 0.9513 - val_loss: 0.1347 - val_accuracy: 0.9522
# Epoch 5/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.1150 - accuracy: 0.9576 - val_loss: 0.1250 - val_accuracy: 0.9535
# Epoch 6/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.1222 - accuracy: 0.9577 - val_loss: 0.1181 - val_accuracy: 0.9565
# Epoch 7/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.1218 - accuracy: 0.9597 - val_loss: 0.1110 - val_accuracy: 0.9583
# Epoch 8/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.1163 - accuracy: 0.9612 - val_loss: 0.1075 - val_accuracy: 0.9600
# Epoch 9/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.1036 - accuracy: 0.9631 - val_loss: 0.1056 - val_accuracy: 0.9583
# Epoch 10/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.1194 - accuracy: 0.9578 - val_loss: 0.0984 - val_accuracy: 0.9635
# Epoch 11/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.1059 - accuracy: 0.9645 - val_loss: 0.0952 - val_accuracy: 0.9626
# Epoch 12/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.1020 - accuracy: 0.9603 - val_loss: 0.0931 - val_accuracy: 0.9617
# Epoch 13/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.1044 - accuracy: 0.9615 - val_loss: 0.0920 - val_accuracy: 0.9639
# Epoch 14/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0969 - accuracy: 0.9644 - val_loss: 0.0894 - val_accuracy: 0.9626
# Epoch 15/50
# 288/288 [==============================] - 2s 6ms/step - loss: 0.0929 - accuracy: 0.9668 - val_loss: 0.0919 - val_accuracy: 0.9643
# Epoch 16/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0866 - accuracy: 0.9682 - val_loss: 0.0861 - val_accuracy: 0.9652
# Epoch 17/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0891 - accuracy: 0.9673 - val_loss: 0.0832 - val_accuracy: 0.9670
# Epoch 18/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0956 - accuracy: 0.9632 - val_loss: 0.0800 - val_accuracy: 0.9691
# Epoch 19/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0904 - accuracy: 0.9693 - val_loss: 0.0800 - val_accuracy: 0.9678
# Epoch 20/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0938 - accuracy: 0.9668 - val_loss: 0.0841 - val_accuracy: 0.9648
# Epoch 21/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0960 - accuracy: 0.9629 - val_loss: 0.0832 - val_accuracy: 0.9661
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 22/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0783 - accuracy: 0.9719 - val_loss: 0.0838 - val_accuracy: 0.9665
# Epoch 23/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0914 - accuracy: 0.9682 - val_loss: 0.0827 - val_accuracy: 0.9670
# Epoch 24/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0820 - accuracy: 0.9686 - val_loss: 0.0809 - val_accuracy: 0.9678
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 25/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0911 - accuracy: 0.9673 - val_loss: 0.0817 - val_accuracy: 0.9674
# Epoch 26/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0836 - accuracy: 0.9681 - val_loss: 0.0811 - val_accuracy: 0.9674
# Epoch 27/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0904 - accuracy: 0.9693 - val_loss: 0.0802 - val_accuracy: 0.9678
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 28/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0781 - accuracy: 0.9713 - val_loss: 0.0828 - val_accuracy: 0.9674
# Epoch 29/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0863 - accuracy: 0.9681 - val_loss: 0.0812 - val_accuracy: 0.9678
# Epoch 30/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0813 - accuracy: 0.9717 - val_loss: 0.0805 - val_accuracy: 0.9678
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 31/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0785 - accuracy: 0.9691 - val_loss: 0.0820 - val_accuracy: 0.9674
# Epoch 32/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0876 - accuracy: 0.9674 - val_loss: 0.0813 - val_accuracy: 0.9674
# Epoch 33/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0931 - accuracy: 0.9651 - val_loss: 0.0817 - val_accuracy: 0.9674
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 34/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0811 - accuracy: 0.9708 - val_loss: 0.0814 - val_accuracy: 0.9674
# Epoch 35/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0897 - accuracy: 0.9692 - val_loss: 0.0817 - val_accuracy: 0.9674
# Epoch 36/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0813 - accuracy: 0.9704 - val_loss: 0.0801 - val_accuracy: 0.9678
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# Epoch 37/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0887 - accuracy: 0.9671 - val_loss: 0.0807 - val_accuracy: 0.9678
# Epoch 38/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0866 - accuracy: 0.9669 - val_loss: 0.0807 - val_accuracy: 0.9678
# Epoch 39/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0800 - accuracy: 0.9701 - val_loss: 0.0811 - val_accuracy: 0.9678
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# Epoch 40/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0911 - accuracy: 0.9691 - val_loss: 0.0811 - val_accuracy: 0.9674
# Epoch 41/50
# 288/288 [==============================] - 2s 6ms/step - loss: 0.0865 - accuracy: 0.9686 - val_loss: 0.0801 - val_accuracy: 0.9678
# Epoch 42/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0953 - accuracy: 0.9673 - val_loss: 0.0804 - val_accuracy: 0.9678
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
# Epoch 43/50
# 288/288 [==============================] - 2s 6ms/step - loss: 0.0938 - accuracy: 0.9670 - val_loss: 0.0818 - val_accuracy: 0.9674
# Epoch 44/50
# 288/288 [==============================] - 2s 6ms/step - loss: 0.0832 - accuracy: 0.9711 - val_loss: 0.0795 - val_accuracy: 0.9678
# Epoch 45/50
# 288/288 [==============================] - 2s 6ms/step - loss: 0.0850 - accuracy: 0.9688 - val_loss: 0.0819 - val_accuracy: 0.9674
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-12.
# Epoch 46/50
# 288/288 [==============================] - 2s 6ms/step - loss: 0.0840 - accuracy: 0.9709 - val_loss: 0.0808 - val_accuracy: 0.9678
# Epoch 47/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0808 - accuracy: 0.9713 - val_loss: 0.0807 - val_accuracy: 0.9678
# Epoch 48/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0883 - accuracy: 0.9665 - val_loss: 0.0814 - val_accuracy: 0.9674
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.0000001044244145e-13.
# Epoch 49/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0849 - accuracy: 0.9683 - val_loss: 0.0819 - val_accuracy: 0.9674
# Epoch 50/50
# 288/288 [==============================] - 2s 5ms/step - loss: 0.0785 - accuracy: 0.9727 - val_loss: 0.0810 - val_accuracy: 0.9678

# %%
train_y_preds = np.argmax(model_eeg.predict(x_train.reshape((x_train.shape[0], x_train.shape[1], 1))), axis = 1)
test_y_preds = np.argmax(model_eeg.predict(x_test.reshape((x_test.shape[0], x_test.shape[1], 1))), axis = 1)

plot_cr_cm(model = model_eeg, x_data = None, y_true = y_train.to_numpy(), labels = [0, 1], target_names = ['Non Epileptic', 'Epileptic'], title = 'SigXNet (Training)', y_preds = train_y_preds)
plot_cr_cm(model = model_eeg, x_data = None, y_true = y_test.to_numpy(), labels = [0, 1], target_names = ['Non Epileptic', 'Epileptic'], title = 'SigXNet (Testing)', y_preds = test_y_preds)

# %%
accuracy = history_eeg.history['accuracy']
val_accuracy = history_eeg.history['val_accuracy']
loss = history_eeg.history['loss']
val_loss = history_eeg.history['val_loss']

epochs = range(len(accuracy))
 
plt.plot(epochs, accuracy, 'r', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
from sklearn.model_selection import validation_curve
from sklearn.model_selection import learning_curve
import warnings
warnings.filterwarnings('ignore')

def plot_with_err(x, data, **kwargs):
    mu, std = data.mean(1), data.std(1)
    lines = plt.plot(x, mu, '-', **kwargs)
    # plt.fill_between(x, mu - std, mu + std, edgecolor='none', facecolor=lines[0].get_color())

def plot_learning_curve(model, scoring = 'accuracy', cv = 2):
    train_sizes = np.linspace(0.05, 1, 20)
    N_train, val_train, val_test = learning_curve(model,
                                                  x_data.to_numpy(), y_data.to_numpy().ravel(), train_sizes = train_sizes, cv = cv,
                                                  scoring = scoring)
    plot_with_err(N_train, val_train, label='Training ' + scoring)
    plot_with_err(N_train, val_test, label='Validation ' + scoring)
    plt.xlabel('Training Set Size'); plt.ylabel(scoring)
    plt.legend()

# %%
plot_learning_curve(pipe_pca_mlp, scoring = 'accuracy', cv = 2)

# %%
plot_learning_curve(pipe_ica_mlp, scoring = 'accuracy', cv = 2)

# %%
plot_learning_curve(pipe_lda_mlp, scoring = 'accuracy', cv = 2)

# %%
plot_learning_curve(pipe_pca_mlp, scoring = 'neg_mean_squared_error', cv = 2)

# %%
import sklearn
sklearn.metrics.SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_root_mean_squared_error', 'neg_mean_poisson_deviance', 'neg_mean_gamma_deviance', 'accuracy', 'roc_auc', 'roc_auc_ovr', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'neg_brier_score', 'adjusted_rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted'])

# %% [markdown]
# ## 2. ECG Classification and Comparison
# => Dataset: Heart Arrhythmias Detection

# %%
train_path = '/content/drive/MyDrive/Datasets/Kaggle ECG dataset/MIT-BIH/mitbih_train.csv' 
test_path = '/content/drive/MyDrive/Datasets/Kaggle ECG dataset/MIT-BIH/mitbih_test.csv'

train_df = pd.read_csv(train_path, header = None)
test_df = pd.read_csv(test_path, header = None)

train_df = train_df.sample(frac=1)

X_train = np.array(train_df[list(range(187))].values)[..., np.newaxis]
Y_train = np.array(train_df[187].values).astype(np.int8)

X_test = np.array(test_df[list(range(187))].values)[..., np.newaxis]
Y_test = np.array(test_df[187].values).astype(np.int8)

# %%
# Standard Scaling Data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train.reshape(X_train.shape[0], X_train.shape[1]))
x_train = scaler.transform(X_train.reshape(X_train.shape[0], X_train.shape[1]))

scaler.fit(X_test.reshape(X_test.shape[0], X_test.shape[1]))
x_test = scaler.transform(X_test.reshape(X_test.shape[0], X_test.shape[1]))

y_train = Y_train
y_test = Y_test

# %%
pipe_pca_mlp.fit(x_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('pca',
#                  PCA(copy=True, iterated_power='auto', n_components=2,
#                      random_state=None, svd_solver='auto', tol=0.0,
#                      whiten=False)),
#                 ('mlp',
#                  MLPClassifier(activation='relu', alpha=0.0001,
#                                batch_size='auto', beta_1=0.9, beta_2=0.999,
#                                early_stopping=False, epsilon=1e-08,
#                                hidden_layer_sizes=(15, 10, 5),
#                                learning_rate='constant',
#                                learning_rate_init=0.001, max_fun=15000,
#                                max_iter=500, momentum=0.9, n_iter_no_change=10,
#                                nesterovs_momentum=True, power_t=0.5,
#                                random_state=None, shuffle=True, solver='adam',
#                                tol=0.0001, validation_fraction=0.1,
#                                verbose=False, warm_start=False))],
#          verbose=False)

# %%
pipe_ica_mlp.fit(x_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('ica',
#                  FastICA(algorithm='parallel', fun='logcosh', fun_args=None,
#                          max_iter=200, n_components=2, random_state=None,
#                          tol=0.0001, w_init=None, whiten=True)),
#                 ('mlp',
#                  MLPClassifier(activation='relu', alpha=0.0001,
#                                batch_size='auto', beta_1=0.9, beta_2=0.999,
#                                early_stopping=False, epsilon=1e-08,
#                                hidden_layer_sizes=(15, 10, 5),
#                                learning_rate='constant',
#                                learning_rate_init=0.001, max_fun=15000,
#                                max_iter=500, momentum=0.9, n_iter_no_change=10,
#                                nesterovs_momentum=True, power_t=0.5,
#                                random_state=None, shuffle=True, solver='adam',
#                                tol=0.0001, validation_fraction=0.1,
#                                verbose=False, warm_start=False))],
#          verbose=False)

# %%
pipe_lda_mlp.fit(x_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('lda',
#                  LinearDiscriminantAnalysis(n_components=1, priors=None,
#                                             shrinkage=None, solver='svd',
#                                             store_covariance=False,
#                                             tol=0.0001)),
#                 ('mlp',
#                  MLPClassifier(activation='relu', alpha=0.0001,
#                                batch_size='auto', beta_1=0.9, beta_2=0.999,
#                                early_stopping=False, epsilon=1e-08,
#                                hidden_layer_sizes=(15, 10, 5),
#                                learning_rate='constant',
#                                learning_rate_init=0.001, max_fun=15000,
#                                max_iter=500, momentum=0.9, n_iter_no_change=10,
#                                nesterovs_momentum=True, power_t=0.5,
#                                random_state=None, shuffle=True, solver='adam',
#                                tol=0.0001, validation_fraction=0.1,
#                                verbose=False, warm_start=False))],
#          verbose=False)

# %%
print('(PCA + MLP) Training Accuracy: ' + str(pipe_pca_mlp.score(x_train, y_train)) + ' Testing Accuracy: ' + str(pipe_pca_mlp.score(x_test, y_test)))
print('(ICA + MLP) Training Accuracy: ' + str(pipe_ica_mlp.score(x_train, y_train)) + ' Testing Accuracy: ' + str(pipe_ica_mlp.score(x_test, y_test)))
print('(LCA + MLP) Training Accuracy: ' + str(pipe_lda_mlp.score(x_train, y_train)) + ' Testing Accuracy: ' + str(pipe_lda_mlp.score(x_test, y_test)))
# Out:
# (PCA + MLP) Training Accuracy: 0.8595952212348951 Testing Accuracy: 0.8579389731408734
# (ICA + MLP) Training Accuracy: 0.8421659775681294 Testing Accuracy: 0.8420884341311895
# (LCA + MLP) Training Accuracy: 0.8928318523425544 Testing Accuracy: 0.8926091723003837

# %%
plot_cr_cm(pipe_pca_mlp, x_train, y_train, [0, 1, 2, 3, 4], ['N', 'S', 'V', 'F', 'Q'], 'PCA + MLP (Training)', model_type = 'sklearn')
plot_cr_cm(pipe_pca_mlp, x_test, y_test, [0, 1, 2, 3, 4], ['N', 'S', 'V', 'F', 'Q'], 'PCA + MLP (Testing)', model_type = 'sklearn')

# %%
plot_cr_cm(pipe_ica_mlp, x_train, y_train, [0, 1, 2, 3, 4], ['N', 'S', 'V', 'F', 'Q'], 'ICA + MLP (Training)', model_type = 'sklearn')
plot_cr_cm(pipe_ica_mlp, x_test, y_test, [0, 1, 2, 3, 4], ['N', 'S', 'V', 'F', 'Q'], 'ICA + MLP (Testing)', model_type = 'sklearn')

# %%
plot_cr_cm(pipe_lda_mlp, x_train, y_train, [0, 1, 2, 3, 4], ['N', 'S', 'V', 'F', 'Q'], 'LDA + MLP (Training)', model_type = 'sklearn')
plot_cr_cm(pipe_lda_mlp, x_test, y_test, [0, 1, 2, 3, 4], ['N', 'S', 'V', 'F', 'Q'], 'LDA + MLP (Testing)', model_type = 'sklearn')

# %%
model_ecg, history_ecg = SigXNet(input_shape=(187, 1), classes=5, X_train=x_train.reshape((x_train.shape[0], x_train.shape[1], 1)), Y_train=y_train, X_test=x_test.reshape((x_test.shape[0], x_test.shape[1], 1)), Y_test=y_test)
# Out:
# Model: "SigXNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# max_pooling1d_6 (MaxPooling1 (None, 93, 1)             0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 87, 26)            208
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 87, 26)            0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 87, 26)            104
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 43, 26)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 39, 13)            1703
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 39, 13)            0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 39, 13)            52
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 19, 13)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 17, 7)             280
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 17, 7)             0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 17, 7)             28
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 119)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 15)                1800
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                160
# _________________________________________________________________
# dense_10 (Dense)             (None, 5)                 55
# _________________________________________________________________
# dense_11 (Dense)             (None, 5)                 30
# =================================================================
# Total params: 4,420
# Trainable params: 4,328
# Non-trainable params: 92
# _________________________________________________________________
# Epoch 1/50
# 2737/2737 [==============================] - 16s 6ms/step - loss: 0.7006 - accuracy: 0.7613 - val_loss: 0.3669 - val_accuracy: 0.9033
# Epoch 2/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.3435 - accuracy: 0.9102 - val_loss: 0.3070 - val_accuracy: 0.9198
# Epoch 3/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.2860 - accuracy: 0.9272 - val_loss: 0.2576 - val_accuracy: 0.9358
# Epoch 4/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.2541 - accuracy: 0.9350 - val_loss: 0.2314 - val_accuracy: 0.9417
# Epoch 5/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.2323 - accuracy: 0.9406 - val_loss: 0.2099 - val_accuracy: 0.9489
# Epoch 6/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.2078 - accuracy: 0.9464 - val_loss: 0.1992 - val_accuracy: 0.9524
# Epoch 7/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1978 - accuracy: 0.9497 - val_loss: 0.1916 - val_accuracy: 0.9522
# Epoch 8/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1831 - accuracy: 0.9538 - val_loss: 0.1805 - val_accuracy: 0.9556
# Epoch 9/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1719 - accuracy: 0.9565 - val_loss: 0.1689 - val_accuracy: 0.9588
# Epoch 10/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1728 - accuracy: 0.9557 - val_loss: 0.1609 - val_accuracy: 0.9593
# Epoch 11/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1564 - accuracy: 0.9606 - val_loss: 0.1562 - val_accuracy: 0.9614
# Epoch 12/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1566 - accuracy: 0.9600 - val_loss: 0.1663 - val_accuracy: 0.9596
# Epoch 13/50
# 2737/2737 [==============================] - 15s 6ms/step - loss: 0.1520 - accuracy: 0.9608 - val_loss: 0.1486 - val_accuracy: 0.9626
# Epoch 14/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1450 - accuracy: 0.9632 - val_loss: 0.1515 - val_accuracy: 0.9619
# Epoch 15/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1433 - accuracy: 0.9633 - val_loss: 0.1416 - val_accuracy: 0.9646
# Epoch 16/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1360 - accuracy: 0.9653 - val_loss: 0.1398 - val_accuracy: 0.9649
# Epoch 17/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1315 - accuracy: 0.9663 - val_loss: 0.1392 - val_accuracy: 0.9648
# Epoch 18/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1329 - accuracy: 0.9660 - val_loss: 0.1538 - val_accuracy: 0.9604
# Epoch 19/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1312 - accuracy: 0.9668 - val_loss: 0.1423 - val_accuracy: 0.9644
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 20/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1263 - accuracy: 0.9672 - val_loss: 0.1288 - val_accuracy: 0.9678
# Epoch 21/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1241 - accuracy: 0.9691 - val_loss: 0.1290 - val_accuracy: 0.9680
# Epoch 22/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1271 - accuracy: 0.9683 - val_loss: 0.1283 - val_accuracy: 0.9676
# Epoch 23/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1247 - accuracy: 0.9690 - val_loss: 0.1278 - val_accuracy: 0.9678
# Epoch 24/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1232 - accuracy: 0.9686 - val_loss: 0.1285 - val_accuracy: 0.9683
# Epoch 25/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1259 - accuracy: 0.9682 - val_loss: 0.1282 - val_accuracy: 0.9681
# Epoch 26/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1239 - accuracy: 0.9682 - val_loss: 0.1280 - val_accuracy: 0.9681
# Epoch 27/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1213 - accuracy: 0.9684 - val_loss: 0.1271 - val_accuracy: 0.9681
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 28/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1212 - accuracy: 0.9690 - val_loss: 0.1270 - val_accuracy: 0.9683
# Epoch 29/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1234 - accuracy: 0.9683 - val_loss: 0.1270 - val_accuracy: 0.9684
# Epoch 30/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1200 - accuracy: 0.9691 - val_loss: 0.1269 - val_accuracy: 0.9683
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 31/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1220 - accuracy: 0.9687 - val_loss: 0.1268 - val_accuracy: 0.9684
# Epoch 32/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1227 - accuracy: 0.9686 - val_loss: 0.1269 - val_accuracy: 0.9684
# Epoch 33/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1224 - accuracy: 0.9690 - val_loss: 0.1269 - val_accuracy: 0.9684
# Epoch 34/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1224 - accuracy: 0.9696 - val_loss: 0.1269 - val_accuracy: 0.9683
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 35/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1201 - accuracy: 0.9694 - val_loss: 0.1269 - val_accuracy: 0.9683
# Epoch 36/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1169 - accuracy: 0.9703 - val_loss: 0.1268 - val_accuracy: 0.9683
# Epoch 37/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1215 - accuracy: 0.9686 - val_loss: 0.1269 - val_accuracy: 0.9683
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# Epoch 38/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1220 - accuracy: 0.9699 - val_loss: 0.1269 - val_accuracy: 0.9683
# Epoch 39/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1204 - accuracy: 0.9702 - val_loss: 0.1269 - val_accuracy: 0.9683
# Epoch 40/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1212 - accuracy: 0.9692 - val_loss: 0.1269 - val_accuracy: 0.9683
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# Epoch 41/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1205 - accuracy: 0.9697 - val_loss: 0.1269 - val_accuracy: 0.9684
# Epoch 42/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1216 - accuracy: 0.9693 - val_loss: 0.1269 - val_accuracy: 0.9683
# Epoch 43/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1202 - accuracy: 0.9700 - val_loss: 0.1269 - val_accuracy: 0.9684
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# Epoch 44/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1215 - accuracy: 0.9696 - val_loss: 0.1269 - val_accuracy: 0.9683
# Epoch 45/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1176 - accuracy: 0.9702 - val_loss: 0.1269 - val_accuracy: 0.9683
# Epoch 46/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1241 - accuracy: 0.9684 - val_loss: 0.1269 - val_accuracy: 0.9685
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
# Epoch 47/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1214 - accuracy: 0.9695 - val_loss: 0.1268 - val_accuracy: 0.9683
# Epoch 48/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1241 - accuracy: 0.9686 - val_loss: 0.1269 - val_accuracy: 0.9684
# Epoch 49/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1228 - accuracy: 0.9687 - val_loss: 0.1269 - val_accuracy: 0.9684
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-12.
# Epoch 50/50
# 2737/2737 [==============================] - 15s 5ms/step - loss: 0.1240 - accuracy: 0.9689 - val_loss: 0.1269 - val_accuracy: 0.9683

# %%
train_y_preds = np.argmax(model_ecg.predict(x_train.reshape((x_train.shape[0], x_train.shape[1], 1))), axis = 1)
test_y_preds = np.argmax(model_ecg.predict(x_test.reshape((x_test.shape[0], x_test.shape[1], 1))), axis = 1)

plot_cr_cm(model = model_ecg, x_data = None, y_true = y_train, labels = [0, 1, 2, 3, 4], target_names = ['N', 'S', 'V', 'F', 'Q'], title = 'SigXNet (Training)', y_preds = train_y_preds)
plot_cr_cm(model = model_ecg, x_data = None, y_true = y_test, labels = [0, 1, 2, 3, 4], target_names = ['N', 'S', 'V', 'F', 'Q'], title = 'SigXNet (Testing)', y_preds = test_y_preds)

# %%
accuracy = history_ecg.history['accuracy']
val_accuracy = history_ecg.history['val_accuracy']
loss = history_ecg.history['loss']
val_loss = history_ecg.history['val_loss']

epochs = range(len(accuracy))
 
plt.plot(epochs, accuracy, 'r', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
plot_learning_curve(pipe_pca_mlp, scoring = 'accuracy', cv = 2)

# %%
plot_learning_curve(pipe_ica_mlp, scoring = 'accuracy', cv = 2)

# %%
plot_learning_curve(pipe_lda_mlp, scoring = 'accuracy', cv = 2)
